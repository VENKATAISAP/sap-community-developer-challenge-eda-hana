# %%
# !python -V
# Out:
# Python 3.9.16

# %%
# !pip install hana-ml

# %%
import hana_ml
print("The package version: ", hana_ml.__version__)
# Out:
# The package version:  2.16.23032300

# %%
import pandas as pd

# %%
from hana_ml import dataframe as hdf

# %%
from hana_ml.dataframe import ConnectionContext

# %%
cc = ConnectionContext('e8c8bf75-fd07-426a-9c7a-7e0d4c6d8562.hana.trial-us10.hanacloud.ondemand.com',443,'','')
print(cc.hana_version())
# Out:
# 4.00.000.00.1678185420 (fa/CE2022.42)

# %%
print(f"Current database schema: {cc.get_current_schema()}")
# Out:
# Current database schema: DEVCHALLENGER

# %%
print(cc.sql("SELECT NOW() FROM DUMMY").collect().CURRENT_TIMESTAMP[0])
# Out:
# 2023-03-27 14:13:59.271000

# %%
cc.get_tables()
# Out:
#   TABLE_NAME
# 0      BIKES
# 1     MONTHS
# 2    SEASONS

# %%
bikes_hdf=cc.table('BIKES')

# %%
bikes_hdf.select_statement
# Out:
# 'SELECT * FROM "BIKES"'

# %% [markdown]
# Understand the dataset

# %%
print(f"DataFrame returns {bikes_hdf.count()} record(s)")
# Out:
# DataFrame returns 731 record(s)

# %%
bikes_hdf.shape
# Out:
# [731, 12]

# %%
bikes_hdf.columns
# Out:
# ['season',
#  'yr',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'hum',
#  'windspeed',
#  'cnt',
#  'days_since_2011']

# %%
bikes_hdf.dtypes()
# Out:
# [('season', 'NVARCHAR', 5000, 5000, 5000, 0),
#  ('yr', 'INT', 10, 10, 10, 0),
#  ('mnth', 'NVARCHAR', 5000, 5000, 5000, 0),
#  ('holiday', 'NVARCHAR', 5000, 5000, 5000, 0),
#  ('weekday', 'NVARCHAR', 5000, 5000, 5000, 0),
#  ('workingday', 'NVARCHAR', 5000, 5000, 5000, 0),
#  ('weathersit', 'NVARCHAR', 5000, 5000, 5000, 0),
#  ('temp', 'DOUBLE', 15, 15, 15, 0),
#  ('hum', 'DOUBLE', 15, 15, 15, 0),
#  ('windspeed', 'DOUBLE', 15, 15, 15, 0),
#  ('cnt', 'INT', 10, 10, 10, 0),
#  ('days_since_2011', 'INT', 10, 10, 10, 0)]

# %%
[col[0] for col in bikes_hdf.dtypes() if col[1]=='NVARCHAR']
# Out:
# ['season', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit']

# %%
bikes_hdf.collect().head(10)
# Out:
#    season    yr mnth     holiday weekday      workingday weathersit      temp  \
# 0  WINTER  2011  JAN  NO HOLIDAY     SAT  NO WORKING DAY      MISTY  8.175849
# 1  WINTER  2011  JAN  NO HOLIDAY     SUN  NO WORKING DAY      MISTY  9.083466
# 2  WINTER  2011  JAN  NO HOLIDAY     MON     WORKING DAY       GOOD  1.229108
# 3  WINTER  2011  JAN  NO HOLIDAY     TUE     WORKING DAY       GOOD  1.400000
# 4  WINTER  2011  JAN  NO HOLIDAY     WED     WORKING DAY       GOOD  2.666979
# 5  WINTER  2011  JAN  NO HOLIDAY     THU     WORKING DAY       GOOD  1.604356
# 6  WINTER  2011  JAN  NO HOLIDAY     FRI     WORKING DAY      MISTY  1.236534
# 7  WINTER  2011  JAN  NO HOLIDAY     SAT  NO WORKING DAY      MISTY -0.245000
# 8  WINTER  2011  JAN  NO HOLIDAY     SUN  NO WORKING DAY       GOOD -1.498349
# 9  WINTER  2011  JAN  NO HOLIDAY     MON     WORKING DAY       GOOD -0.910849
#
#        hum  windspeed   cnt  days_since_2011
# 0  80.5833  10.749882   985                0
# 1  69.6087  16.652113   801                1
# 2  43.7273  16.636703  1349                2
# 3  59.0435  10.739832  1562                3
# 4  43.6957  12.522300  1600                4
# 5  51.8261   6.000868  1606                5
# 6  49.8696  11.304642  1510                6
# 7  53.5833  17.875868   959                7
# 8  43.4167  24.250650   822                8
# 9  48.2917  14.958889  1321                9

# %%
bikes_hdf.head(10).select_statement
# Out:
# 'SELECT TOP 10 * FROM (SELECT * FROM "BIKES") dt'

# %%
bikes_hdf.tail(5, ref_col='days_since_2011').collect()
# Out:
#    season    yr mnth     holiday weekday      workingday weathersit      temp  \
# 0  WINTER  2012  DEC  NO HOLIDAY     THU     WORKING DAY      MISTY  3.945849
# 1  WINTER  2012  DEC  NO HOLIDAY     FRI     WORKING DAY      MISTY  3.906651
# 2  WINTER  2012  DEC  NO HOLIDAY     SAT  NO WORKING DAY      MISTY  3.906651
# 3  WINTER  2012  DEC  NO HOLIDAY     SUN  NO WORKING DAY       GOOD  4.024151
# 4  WINTER  2012  DEC  NO HOLIDAY     MON     WORKING DAY      MISTY  2.144151
#
#        hum  windspeed   cnt  days_since_2011
# 0  65.2917  23.458911  2114              726
# 1  59.0000  10.416557  3095              727
# 2  75.2917   8.333661  1341              728
# 3  48.3333  23.500518  1796              729
# 4  57.7500  10.374682  2729              730

# %%
bikes_hdf.tail(5, ref_col='days_since_2011').select_statement
# Out:
# 'SELECT "season", "yr", "mnth", "holiday", "weekday", "workingday", "weathersit", "temp", "hum", "windspeed", "cnt", "days_since_2011" FROM (SELECT  ROW_NUMBER() OVER(ORDER BY "days_since_2011" ASC) IDX9F37F62C_CCA9_11ED_AD58_0242AC1C000C , * FROM (SELECT * FROM "BIKES")) WHERE IDX9F37F62C_CCA9_11ED_AD58_0242AC1C000C <= 731 AND IDX9F37F62C_CCA9_11ED_AD58_0242AC1C000C > 726'

# %%
bikes_hdf.hasna()
# Out:
# False

# %%
for col in bikes_hdf.columns:
    print(f"NULLs in {col}: {bikes_hdf.hasna(col)}")
# Out:
# NULLs in season: False
# NULLs in yr: False
# NULLs in mnth: False
# NULLs in holiday: False
# NULLs in weekday: False
# NULLs in workingday: False
# NULLs in weathersit: False
# NULLs in temp: False
# NULLs in hum: False
# NULLs in windspeed: False
# NULLs in cnt: False
# NULLs in days_since_2011: False

# %%
bikes_hdf.describe().collect()
# Out:
#              column  count  unique  nulls         mean          std  \
# 0                yr    731       2      0  2011.500684     0.500341
# 1              temp    731     499      0    15.283085     8.603397
# 2               hum    731     595      0    62.789406    14.242910
# 3         windspeed    731     650      0    12.762576     5.192357
# 4               cnt    731     696      0  4504.348837  1937.211451
# 5   days_since_2011    731     731      0   365.000000   211.165811
# 6            season    731       4      0          NaN          NaN
# 7              mnth    731      12      0          NaN          NaN
# 8           holiday    731       2      0          NaN          NaN
# 9           weekday    731       7      0          NaN          NaN
# 10       workingday    731       2      0          NaN          NaN
# 11       weathersit    731       3      0          NaN          NaN
#
#             min          max       median  25_percent_cont  25_percent_disc  \
# 0   2011.000000  2012.000000  2012.000000      2011.000000      2011.000000
# 1     -5.220871    32.498349    15.421651         7.842924         7.823349
# 2      0.000000    97.250000    62.666700        52.000000        52.000000
# 3      1.500244    34.000021    12.125325         9.041650         9.041650
# 4     22.000000  8714.000000  4548.000000      3152.000000      3141.000000
# 5      0.000000   730.000000   365.000000       182.500000       182.000000
# 6           NaN          NaN          NaN              NaN              NaN
# 7           NaN          NaN          NaN              NaN              NaN
# 8           NaN          NaN          NaN              NaN              NaN
# 9           NaN          NaN          NaN              NaN              NaN
# 10          NaN          NaN          NaN              NaN              NaN
# 11          NaN          NaN          NaN              NaN              NaN
#
#     50_percent_cont  50_percent_disc  75_percent_cont  75_percent_disc
# 0       2012.000000      2012.000000      2012.000000      2012.000000
# 1         15.421651        15.421651        22.804576        22.824151
# 2         62.666700        62.666700        73.020850        73.041700
# 3         12.125325        12.125325        15.625371        15.625807
# 4       4548.000000      4548.000000      5956.000000      5976.000000
# 5        365.000000       365.000000       547.500000       548.000000
# 6               NaN              NaN              NaN              NaN
# 7               NaN              NaN              NaN              NaN
# 8               NaN              NaN              NaN              NaN
# 9               NaN              NaN              NaN              NaN
# 10              NaN              NaN              NaN              NaN
# 11              NaN              NaN              NaN              NaN

# %%
bikes_hdf.describe().select_statement
# Out:
# 'SELECT * FROM (SELECT "SimpleStats".*, "Percentiles"."25_percent_cont", "Percentiles"."25_percent_disc", "Percentiles"."50_percent_cont", "Percentiles"."50_percent_disc", "Percentiles"."75_percent_cont", "Percentiles"."75_percent_disc" FROM (select \'yr\' as "column", COUNT("yr") as "count", COUNT(DISTINCT "yr") as "unique", SUM(CASE WHEN "yr" is NULL THEN 1 ELSE 0 END) as "nulls", AVG(TO_DOUBLE("yr")) as "mean", STDDEV("yr") as "std", MIN("yr") as "min", MAX("yr") as "max", MEDIAN("yr") as "median" FROM (SELECT * FROM "BIKES") AS "DT_5" UNION ALL select \'temp\' as "column", COUNT("temp") as "count", COUNT(DISTINCT "temp") as "unique", SUM(CASE WHEN "temp" is NULL THEN 1 ELSE 0 END) as "nulls", AVG(TO_DOUBLE("temp")) as "mean", STDDEV("temp") as "std", MIN("temp") as "min", MAX("temp") as "max", MEDIAN("temp") as "median" FROM (SELECT * FROM "BIKES") AS "DT_5" UNION ALL select \'hum\' as "column", COUNT("hum") as "count", COUNT(DISTINCT "hum") as "unique", SUM(CASE WHEN "hum" is NULL THEN 1 ELSE 0 END) as "nulls", AVG(TO_DOUBLE("hum")) as "mean", STDDEV("hum") as "std", MIN("hum") as "min", MAX("hum") as "max", MEDIAN("hum") as "median" FROM (SELECT * FROM "BIKES") AS "DT_5" UNION ALL select \'windspeed\' as "column", COUNT("windspeed") as "count", COUNT(DISTINCT "windspeed") as "unique", SUM(CASE WHEN "windspeed" is NULL THEN 1 ELSE 0 END) as "nulls", AVG(TO_DOUBLE("windspeed")) as "mean", STDDEV("windspeed") as "std", MIN("windspeed") as "min", MAX("windspeed") as "max", MEDIAN("windspeed") as "median" FROM (SELECT * FROM "BIKES") AS "DT_5" UNION ALL select \'cnt\' as "column", COUNT("cnt") as "count", COUNT(DISTINCT "cnt") as "unique", SUM(CASE WHEN "cnt" is NULL THEN 1 ELSE 0 END) as "nulls", AVG(TO_DOUBLE("cnt")) as "mean", STDDEV("cnt") as "std", MIN("cnt") as "min", MAX("cnt") as "max", MEDIAN("cnt") as "median" FROM (SELECT * FROM "BIKES") AS "DT_5" UNION ALL select \'days_since_2011\' as "column", COUNT("days_since_2011") as "count", COUNT(DISTINCT "days_since_2011") as "unique", SUM(CASE WHEN "days_since_2011" is NULL THEN 1 ELSE 0 END) as "nulls", AVG(TO_DOUBLE("days_since_2011")) as "mean", STDDEV("days_since_2011") as "std", MIN("days_since_2011") as "min", MAX("days_since_2011") as "max", MEDIAN("days_since_2011") as "median" FROM (SELECT * FROM "BIKES") AS "DT_5") AS "SimpleStats", (SELECT \'yr\' as "column", * FROM (SELECT percentile_cont(0.25) WITHIN GROUP (ORDER BY "yr") AS "25_percent_cont", percentile_disc(0.25) WITHIN GROUP (ORDER BY "yr") AS "25_percent_disc", percentile_cont(0.50) WITHIN GROUP (ORDER BY "yr") AS "50_percent_cont", percentile_disc(0.50) WITHIN GROUP (ORDER BY "yr") AS "50_percent_disc", percentile_cont(0.75) WITHIN GROUP (ORDER BY "yr") AS "75_percent_cont", percentile_disc(0.75) WITHIN GROUP (ORDER BY "yr") AS "75_percent_disc" FROM (SELECT * FROM "BIKES") AS "DT_5") UNION ALL SELECT \'temp\' as "column", * FROM (SELECT percentile_cont(0.25) WITHIN GROUP (ORDER BY "temp") AS "25_percent_cont", percentile_disc(0.25) WITHIN GROUP (ORDER BY "temp") AS "25_percent_disc", percentile_cont(0.50) WITHIN GROUP (ORDER BY "temp") AS "50_percent_cont", percentile_disc(0.50) WITHIN GROUP (ORDER BY "temp") AS "50_percent_disc", percentile_cont(0.75) WITHIN GROUP (ORDER BY "temp") AS "75_percent_cont", percentile_disc(0.75) WITHIN GROUP (ORDER BY "temp") AS "75_percent_disc" FROM (SELECT * FROM "BIKES") AS "DT_5") UNION ALL SELECT \'hum\' as "column", * FROM (SELECT percentile_cont(0.25) WITHIN GROUP (ORDER BY "hum") AS "25_percent_cont", percentile_disc(0.25) WITHIN GROUP (ORDER BY "hum") AS "25_percent_disc", percentile_cont(0.50) WITHIN GROUP (ORDER BY "hum") AS "50_percent_cont", percentile_disc(0.50) WITHIN GROUP (ORDER BY "hum") AS "50_percent_disc", percentile_cont(0.75) WITHIN GROUP (ORDER BY "hum") AS "75_percent_cont", percentile_disc(0.75) WITHIN GROUP (ORDER BY "hum") AS "75_percent_disc" FROM (SELECT * FROM "BIKES") AS "DT_5") UNION ALL SELECT \'windspeed\' as "column", * FROM (SELECT pe ...

# %% [markdown]
# Closer look at properties of columns in a dataframe

# %% [markdown]
# Check statistics only for columns storing strings

# %%
bikes_hdf.describe([col[0] for col in bikes_hdf.dtypes() if col[1]=='NVARCHAR']).collect().dropna(axis=1,how='all')
# Out:
#        column  count  unique  nulls
# 0      season    731       4      0
# 1        mnth    731      12      0
# 2     holiday    731       2      0
# 3     weekday    731       7      0
# 4  workingday    731       2      0
# 5  weathersit    731       3      0

# %%
(bikes_hdf.describe([col[0] for col in bikes_hdf.dtypes() if col[1] == 'NVARCHAR']).collect()
 #.dropna(axis=1,how='all') # uncomment this line to see the difference
 .set_index('column')
)
# Out:
#             count  unique  nulls  mean   std   min   max median  \
# column
# season        731       4      0  None  None  None  None   None
# mnth          731      12      0  None  None  None  None   None
# holiday       731       2      0  None  None  None  None   None
# weekday       731       7      0  None  None  None  None   None
# workingday    731       2      0  None  None  None  None   None
# weathersit    731       3      0  None  None  None  None   None
#
#            25_percent_cont 25_percent_disc 50_percent_cont 50_percent_disc  \
# column
# season                None            None            None            None
# mnth                  None            None            None            None
# holiday               None            None            None            None
# weekday               None            None            None            None
# workingday            None            None            None            None
# weathersit            None            None            None            None
#
#            75_percent_cont 75_percent_disc
# column
# season                None            None
# mnth                  None            None
# holiday               None            None
# weekday               None            None
# workingday            None            None
# weathersit            None            None

# %%
(bikes_hdf.describe([col[0] for col in bikes_hdf.dtypes() if col[1] == 'NVARCHAR']).collect()
 .dropna(axis=1,how='all') # uncomment this line to see the difference
 .set_index('column')
)
# Out:
#             count  unique  nulls
# column
# season        731       4      0
# mnth          731      12      0
# holiday       731       2      0
# weekday       731       7      0
# workingday    731       2      0
# weathersit    731       3      0

# %%
bikes_hdf.distinct(cols='season').collect()
# Out:
#    season
# 0  SUMMER
# 1    FALL
# 2  SPRING
# 3  WINTER

# %%
for column in [col[0] for col in bikes_hdf.dtypes() if col[1]=='NVARCHAR']:
    print(f"{column}: {bikes_hdf.distinct(column).collect().iloc[:,0].tolist()}")
# Out:
# season: ['SUMMER', 'FALL', 'SPRING', 'WINTER']
# mnth: ['APR', 'AUG', 'DEC', 'FEB', 'JAN', 'JUL', 'JUN', 'MAR', 'MAY', 'NOV', 'OCT', 'SEP']
# holiday: ['HOLIDAY', 'NO HOLIDAY']
# weekday: ['FRI', 'TUE', 'SUN', 'THU', 'WED', 'MON', 'SAT']
# workingday: ['NO WORKING DAY', 'WORKING DAY']
# weathersit: ['MISTY', 'GOOD', 'RAIN/SNOW/STORM']

# %%
bikes_hdf.value_counts(['weathersit']).collect()
# Out:
#             VALUES  NUM_weathersit
# 0            MISTY             247
# 1             GOOD             463
# 2  RAIN/SNOW/STORM              21

# %% [markdown]
# Now check basic characteristics of numeric values in columns.

# %%
(bikes_hdf
 .describe([col[0] for col in bikes_hdf.dtypes() if col[1]!='NVARCHAR'])
 .collect()
 .iloc[:,:9]
 .set_index('column')
)
# Out:
#                  count  unique  nulls         mean          std          min  \
# column
# yr                 731       2      0  2011.500684     0.500341  2011.000000
# temp               731     499      0    15.283085     8.603397    -5.220871
# hum                731     595      0    62.789406    14.242910     0.000000
# windspeed          731     650      0    12.762576     5.192357     1.500244
# cnt                731     696      0  4504.348837  1937.211451    22.000000
# days_since_2011    731     731      0   365.000000   211.165811     0.000000
#
#                          max       median
# column
# yr               2012.000000  2012.000000
# temp               32.498349    15.421651
# hum                97.250000    62.666700
# windspeed          34.000021    12.125325
# cnt              8714.000000  4548.000000
# days_since_2011   730.000000   365.000000

# %%
(bikes_hdf
 .select('hum').sort('hum')
 .bin('hum', strategy='uniform_number', bins=10)
 .collect()
)
# Out:
#          hum  BIN_NUMBER
# 0     0.0000           1
# 1    18.7917           2
# 2    25.4167           3
# 3    27.5833           3
# 4    29.0000           3
# ..       ...         ...
# 726  94.8261          10
# 727  94.9583          10
# 728  96.2500          10
# 729  97.0417          10
# 730  97.2500          10
#
# [731 rows x 2 columns]

# %%
(bikes_hdf
 .select('hum').sort('hum')
 .bin('hum', strategy='uniform_number', bins=10)
 .value_counts(subset=['BIN_NUMBER'])
 .collect().set_index('VALUES')
)
# Out:
#         NUM_BIN_NUMBER
# VALUES
# 1                    1
# 2                    1
# 3                    3
# 4                   18
# 5                   95
# 6                  173
# 7                  164
# 8                  169
# 9                   73
# 10                  34

# %% [markdown]
#  Understand the data

# %%
bikes_hdf.filter(condition='"yr"=2011').count()
# Out:
# 365

# %%
bikes_hdf.filter('"yr"=2011 AND "holiday"=\'HOLIDAY\'').collect()
# Out:
#    season    yr mnth  holiday weekday      workingday weathersit       temp  \
# 0  WINTER  2011  JAN  HOLIDAY     MON  NO WORKING DAY      MISTY   0.264151
# 1  WINTER  2011  FEB  HOLIDAY     MON  NO WORKING DAY      MISTY   6.256651
# 2  SPRING  2011  APR  HOLIDAY     FRI  NO WORKING DAY       GOOD  12.993349
# 3  SPRING  2011  MAY  HOLIDAY     MON  NO WORKING DAY       GOOD  26.466651
# 4  SUMMER  2011  JUL  HOLIDAY     MON  NO WORKING DAY      MISTY  26.153349
# 5  SUMMER  2011  SEP  HOLIDAY     MON  NO WORKING DAY      MISTY  23.646651
# 6    FALL  2011  OCT  HOLIDAY     MON  NO WORKING DAY       GOOD  18.829151
# 7    FALL  2011  NOV  HOLIDAY     FRI  NO WORKING DAY       GOOD   7.235849
# 8    FALL  2011  NOV  HOLIDAY     THU  NO WORKING DAY       GOOD   9.546651
# 9  WINTER  2011  DEC  HOLIDAY     MON  NO WORKING DAY       GOOD   7.121733
#
#        hum  windspeed   cnt  days_since_2011
# 0  53.7500  12.999139  1000               16
# 1  60.5000  20.625682  1107               51
# 2  67.1250  15.167125  3126              104
# 3  68.5000   8.792075  4098              149
# 4  63.7917   5.459106  6043              184
# 5  79.0417  14.250632  3351              247
# 6  73.3750   2.834381  5117              282
# 7  44.6250  21.083225  3368              314
# 8  54.9167  11.209368  1495              327
# 9  50.6957  16.044155  1317              359

# %% [markdown]
# Projection

# %%
(bikes_hdf
 .filter('"yr"=2011 AND "holiday"=\'HOLIDAY\'')
 .select('weekday', 'days_since_2011')
 .collect()
)
# Out:
#   weekday  days_since_2011
# 0     MON               16
# 1     MON               51
# 2     FRI              104
# 3     MON              149
# 4     MON              184
# 5     MON              247
# 6     MON              282
# 7     FRI              314
# 8     THU              327
# 9     MON              359

# %% [markdown]
# In the example below a new column calday is calculated using the SAP HANA SQL ADD_DAYS function to add number from the "days_since_2011" column to the date 2011-01-01.

# %%
(bikes_hdf
 .filter('"yr"=2011 AND "holiday"=\'HOLIDAY\'')
 .select('weekday', ('ADD_DAYS(\'2011-01-01\',"days_since_2011")', 'calday'))
 .collect()
)
# Out:
#   weekday      calday
# 0     MON  2011-01-17
# 1     MON  2011-02-21
# 2     FRI  2011-04-15
# 3     MON  2011-05-30
# 4     MON  2011-07-04
# 5     MON  2011-09-05
# 6     MON  2011-10-10
# 7     FRI  2011-11-11
# 8     THU  2011-11-24
# 9     MON  2011-12-26

# %%
bikebydays_hdf=bikes_hdf.select('*', ('add_days(\'2011-01-01\',"days_since_2011")', 'calday'))

# %%
bikebydays_hdf.select_statement
# Out:
# 'SELECT "season", "yr", "mnth", "holiday", "weekday", "workingday", "weathersit", "temp", "hum", "windspeed", "cnt", "days_since_2011", add_days(\'2011-01-01\',"days_since_2011") AS "calday" FROM (SELECT * FROM "BIKES") AS "DT_5"'

# %% [markdown]
# Use this HANA DataFrame bikebydays_hdf to query holidays in 2012.

# %%
(bikebydays_hdf
 .filter('"yr"=2012 AND "holiday"=\'HOLIDAY\'')
 .select('weekday')
 .collect()
)
# Out:
#    weekday
# 0      MON
# 1      MON
# 2      MON
# 3      MON
# 4      MON
# 5      WED
# 6      MON
# 7      MON
# 8      MON
# 9      THU
# 10     TUE

# %%
bikebydays_hdf.deselect('days_since_2011').sort(cols='cnt', desc=False).head(5).collect()
# Out:
#    season    yr mnth     holiday weekday      workingday       weathersit  \
# 0    FALL  2012  OCT  NO HOLIDAY     MON     WORKING DAY  RAIN/SNOW/STORM
# 1  WINTER  2011  JAN  NO HOLIDAY     THU     WORKING DAY             GOOD
# 2  WINTER  2012  DEC  NO HOLIDAY     WED     WORKING DAY  RAIN/SNOW/STORM
# 3  WINTER  2011  JAN  NO HOLIDAY     WED     WORKING DAY  RAIN/SNOW/STORM
# 4  WINTER  2011  MAR  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#
#         temp      hum  windspeed  cnt      calday
# 0  12.680000  88.0000  23.999400   22  2012-10-29
# 1   1.165000  68.7500   7.627079  431  2011-01-27
# 2   3.436651  82.3333  21.208582  441  2012-12-26
# 3   2.222500  86.2500  19.687950  506  2011-01-26
# 4   9.696534  94.8261  23.000229  605  2011-03-06

# %% [markdown]
# What is the smallest count of bikes rented during one day?

# %% [markdown]
# 22

# %% [markdown]
# Joining

# %%
bikes_hdf.filter('''
"season"='SUMMER' AND "yr"=2012
''').distinct('mnth').collect()
# Out:
#   mnth
# 0  AUG
# 1  JUL
# 2  JUN
# 3  SEP

# %%
(bikebydays_hdf.filter('''
"season"='SUMMER' AND "yr"=2012
''')
 .agg(
     [('min', 'calday', 'MIN'),
      ('max', 'calday', 'MAX')], 
     group_by=['mnth']
 )
 .collect()
)
# Out:
#   mnth         MIN         MAX
# 0  AUG  2012-08-01  2012-08-31
# 1  JUL  2012-07-01  2012-07-31
# 2  JUN  2012-06-21  2012-06-30
# 3  SEP  2012-09-01  2012-09-22

# %%
cc.table('MONTHS').collect()
# Out:
#     ID DESC
# 0    1  JAN
# 1    2  FEB
# 2    3  MAR
# 3    4  APR
# 4    5  MAY
# 5    6  JUN
# 6    7  JUL
# 7    8  AUG
# 8    9  SEP
# 9   10  OCT
# 10  11  NOV
# 11  12  DEC

# %%
bikebydays_hdf.filter('''
"season"='SUMMER' AND "yr"=2012
''').agg(
     [('min', 'calday', 'MIN'),
      ('max', 'calday', 'MAX')], 
     group_by=['mnth'] ).join(other=cc.table('MONTHS'), condition='"mnth"="DESC"', 
       select=['ID', ('DESC', 'MONTH'), 'MIN', 'MAX']).sort('ID').collect().set_index('ID')
# Out:
#    MONTH         MIN         MAX
# ID
# 6    JUN  2012-06-21  2012-06-30
# 7    JUL  2012-07-01  2012-07-31
# 8    AUG  2012-08-01  2012-08-31
# 9    SEP  2012-09-01  2012-09-22
